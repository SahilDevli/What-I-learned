# %%
import pandas as pd
import numpy as np

# %%
dic = {
    'id':[201,202,203,204],
    'name':['sahil','tarun','aman','devesh'],
    'age':[21,20,19,22]
}
print(dic)
df = pd.DataFrame(dic)
print(df)
# Out:
# {'id': [201, 202, 203, 204], 'name': ['sahil', 'tarun', 'aman', 'devesh'], 'age': [21, 20, 19, 22]}
#     id    name  age
# 0  201   sahil   21
# 1  202   tarun   20
# 2  203    aman   19
# 3  204  devesh   22
